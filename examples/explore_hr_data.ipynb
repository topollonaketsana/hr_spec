# %% [markdown]
# ### Stellar Spectral Classification

# %% [markdown]
# This notebook demonstrates how to use the `hr_spec` package for classifying stars based on physical parameters such as temperature, luminosity, radius, and color.
#
# We call our classifier defined in this file `classifier.py`, and train it on a sample dataset using `training_model.py`.
# ___________________________________________________________________________________________________________________________________

# %%
'''
Make sure you have successfully installed the package and its packages - see the following (uncomment)
'''
# Out:
# '\nMake sure you have successfully installed the package and its packages\n'

# %%
#!pip install -e .
#!pip install -r requirements.txt

# %% [markdown]
# #### 1. Load and understand the input dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
from hr_spec.ml.classifier import KNNClassifier
from hr_spec.ml.train_model import train_star_classifier
